// %% [markdown]
// # Syntactic suggar in functions

// %% [markdown]
// ## Invocación de métodos

// %%
class Azucar {
  def f1(a: Int): Int = a
}
// Out:
// defined class Azucar

// %% [markdown]
// If no parameters are needed, you don't need parenthesis

// %%
val azucar = new Azucar
// Out:
// azucar: Azucar = ammonite.$sess.cmd1$Helper$Azucar@11083abc

// %% [markdown]
// Multiple ways to call methods

// %%
azucar.f1(1)
// Out:
// res3: Int = 1

// %%
azucar.f1{1}
azucar.f1({1})
// Out:
// res5_0: Int = 1
// res5_1: Int = 1

// %%
azucar f1 1
// Out:
// res6: Int = 1

// %% [markdown]
// A normal function

// %%
def f1(a: Int): Int = a
// Out:
// defined function f1

// %%
f1(10)
// Out:
// res1: Int = 10

// %% [markdown]
// Multiple params, call by parameter name

// %%
class Azucar {
  def f2(a: Boolean, b: String, c: String): String =
    if (a) b else c
}

val azucar = new Azucar
// Out:
// defined class Azucar
// azucar: Azucar = ammonite.$sess.cmd7$Helper$Azucar@64d2619f

// %%
azucar.f2(true, "hello", "bye")
azucar.f2(false, "hello", "bye")
azucar.f2(true, c = "bye", b = "hello")
azucar f2 (true, "hello", "bye")
// Out:
// res8_0: String = "hello"
// res8_1: String = "bye"
// res8_2: String = "hello"
// res8_3: String = "hello"

// %% [markdown]
// Default parameters values

// %%
def f3(a: Boolean, b: String = "then", c: String = "else"): String = {
    if (a) b else c
  }
// Out:
// defined function f3

// %%
f3(true, "hello", "bye")
f3(true, "hello")
f3(true)
f3(true, c = "bye")
// Out:
// cmd1.sc:5: not enough arguments for method f3: (a: Boolean, b: String, c: String)String.
// Unspecified value parameter a.
// val res1_4 = f3(c= "bye", true)
//                ^Compilation Failed
// Compilation Failed

// %% [markdown]
// Variadric

// %%
def f4(a: Int*): Int = a.reduce { (a1, a2) =>
    a1 + a2
  }
// Out:
// defined function f4

// %%
f4(1,2,3,4)
f4(1)
f4(List(1,2,3,4):_*)
//f4() error!!!!
// Out:
// res14_0: Int = 10
// res14_1: Int = 1
// res14_2: Int = 10
